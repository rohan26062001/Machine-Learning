# %% [markdown]
# # Matplotlib Tutorial

# %%
# Includng Libraries
import matplotlib.pyplot as plt

# %%
# Plotting to our Canvas
x = [1,2,3]
y = [4,5,1]
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('First Graph')
plt.plot(x,y)

# %%
# Including Style from Matplotlib
from matplotlib import style
style.use("ggplot")

# %%
# Plotting to Our Canvas
x1 = [1,2,3]
y1 = [4,5,1]

x2 = [8,3,6]
y2 = [45, 5, 89]

plt.plot(x1,y1,'g',label="First Line", linewidth=2)
plt.plot(x2,y2,'c',label="Second Line", linewidth=3)

plt.legend()

plt.title('Second Graph')

plt.grid(True, 'K')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2688/1928590075.py in <module>
#      11 plt.title('Second Graph')
#      12
# ---> 13 plt.grid(True, 'K')
#      14
#      15 plt.legend(True)
#
# c:\users\admin\appdata\local\programs\python\python39\lib\site-packages\matplotlib\pyplot.py in grid(b, which, axis, **kwargs)
#    2822 @_copy_docstring_and_deprecators(Axes.grid)
#    2823 def grid(b=None, which='major', axis='both', **kwargs):
# -> 2824     return gca().grid(b=b, which=which, axis=axis, **kwargs)
#    2825
#    2826
#
# c:\users\admin\appdata\local\programs\python\python39\lib\site-packages\matplotlib\axes\_base.py in grid(self, b, which, axis, **kwargs)
#    3062         _api.check_in_list(['x', 'y', 'both'], axis=axis)
#    3063         if axis in ['x', 'both']:
# -> 3064             self.xaxis.grid(b, which=which, **kwargs)
#    3065         if axis in ['y', 'both']:
#    3066             self.yaxis.grid(b, which=which, **kwargs)
#
# c:\users\admin\appdata\local\programs\python\python39\lib\site-packages\matplotlib\axis.py in grid(self, b, which, **kwargs)
#    1417
#    1418         which = which.lower()
# -> 1419         _api.check_in_list(['major', 'minor', 'both'], which=which)
#    1420         gridkw = {'grid_' + item[0]: item[1] for item in kwargs.items()}
#    1421         if which in ['minor', 'both']:
#
# c:\users\admin\appdata\local\programs\python\python39\lib\site-packages\matplotlib\_api\__init__.py in check_in_list(_values, _print_supported_values, **kwargs)
#     124         if val not in values:
#     125             if _print_supported_values:
# --> 126                 raise ValueError(
#     127                     f"{val!r} is not a valid value for {key}; "
#     128                     f"supported values are {', '.join(map(repr, values))}")
#
# ValueError: 'k' is not a valid value for which; supported values are 'major', 'minor', 'both'
